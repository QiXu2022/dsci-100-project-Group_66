# %%
library(tidyverse)
library(repr)
library(tidymodels)
# Out:
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.0.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.2     ✔ workflows    1.0.0
# ✔ modeldata    1.0.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.0     ✔ yardstick    1.0.0
# ✔ recipes      1.0.1
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use suppressPackageStartupMessages() to eliminate package startup messages

# %%
heart_disease_data <- read_csv("https://github.com/QiXu2022/dsci-100-project-Group_66/blob/main/heart_disease_uci.csv")
heart_disease_data
# Out:
# Warning message:
# “One or more parsing issues, see `problems()` for details”
# Rows: 18721 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): <!DOCTYPE html>
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# ...

# %%
tidy_data<-heart_disease_data |>
    filter(dataset=="Cleveland") |>
    select(sex, trestbps, chol, restecg, num) 
tidy_data
# Out:
#     sex    trestbps chol restecg          num
# 1   Male   145      233  lv hypertrophy   0
# 2   Male   160      286  lv hypertrophy   2
# 3   Male   120      229  lv hypertrophy   1
# 4   Male   130      250  normal           0
# 5   Female 130      204  lv hypertrophy   0
# 6   Male   120      236  normal           0
# 7   Female 140      268  lv hypertrophy   3
# 8   Female 120      354  normal           0
# 9   Male   130      254  lv hypertrophy   2
# 10  Male   140      203  lv hypertrophy   1
# 11  Male   140      192  normal           0
# 12  Female 140      294  lv hypertrophy   0
# 13  Male   130      256  lv hypertrophy   2
# 14  Male   120      263  normal           0
# 15  Male   172      199  normal           0
# 16  Male   150      168  normal           0
# 17  Male   110      229  normal           1
# 18  Male   140      239  normal           0
# 19  Female 130      275  normal           0
# 20  Male   130      266  normal           0
# ...
